# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# %%
df = pd.read_csv('data.csv')
df.describe()
# Out:
#          timestamp        steer     throttle        break
# count  1773.000000  1773.000000  1773.000000  1773.000000
# mean   2462.147447     0.000646     0.387038     0.095321
# std    1412.913435     0.084002     0.174124     0.293041
# min      14.849083    -0.336534     0.000000     0.000000
# 25%    1291.849083    -0.001640     0.379370     0.000000
# 50%    2546.849083     0.000000     0.379372     0.000000
# 75%    3703.849083     0.001856     0.383970     0.000000
# max    4916.849083     0.511645     0.700000     1.000000

# %%
df.head(10)
# Out:
#    timestamp  steer  throttle  break
# 0  14.849083    0.0       0.0    0.0
# 1  15.849083    0.0       0.0    0.0
# 2  17.849083    0.0       0.0    0.0
# 3  17.849083    0.0       0.0    0.0
# 4  18.849083    0.0       0.0    0.0
# 5  19.849083    0.0       0.0    0.0
# 6  20.849083    0.0       0.0    0.0
# 7  21.849083    0.0       0.0    0.0
# 8  22.849083    0.0       0.0    0.0
# 9  24.849083    0.0       0.0    0.0

# %%
df.describe()
# Out:
#          timestamp        steer     throttle        break
# count  1773.000000  1773.000000  1773.000000  1773.000000
# mean   2462.147447     0.000646     0.387038     0.095321
# std    1412.913435     0.084002     0.174124     0.293041
# min      14.849083    -0.336534     0.000000     0.000000
# 25%    1291.849083    -0.001640     0.379370     0.000000
# 50%    2546.849083     0.000000     0.379372     0.000000
# 75%    3703.849083     0.001856     0.383970     0.000000
# max    4916.849083     0.511645     0.700000     1.000000

# %%
df.drop_duplicates(subset = "timestamp", keep = 'last', inplace = True)
df.describe()
# Out:
#          timestamp        steer     throttle        break
# count  1755.000000  1755.000000  1755.000000  1755.000000
# mean   2472.971020     0.000649     0.387471     0.096299
# std    1410.469514     0.084430     0.173614     0.294381
# min      14.849083    -0.336534     0.000000     0.000000
# 25%    1299.349083    -0.001641     0.379370     0.000000
# 50%    2567.849083     0.000000     0.379372     0.000000
# 75%    3713.349083     0.001921     0.383999     0.000000
# max    4916.849083     0.511645     0.700000     1.000000

# %%
df.head(10)
# Out:
#     timestamp  steer  throttle  break
# 0   14.849083    0.0       0.0    0.0
# 1   15.849083    0.0       0.0    0.0
# 3   17.849083    0.0       0.0    0.0
# 4   18.849083    0.0       0.0    0.0
# 5   19.849083    0.0       0.0    0.0
# 6   20.849083    0.0       0.0    0.0
# 7   21.849083    0.0       0.0    0.0
# 8   22.849083    0.0       0.0    0.0
# 10  24.849083    0.0       0.0    0.0
# 11  25.849083    0.0       0.0    0.0

# %%
df['timestamp'] = df['timestamp'].astype("int")

# %%
df.head(10)
# Out:
#     timestamp  steer  throttle  break
# 0          14    0.0       0.0    0.0
# 1          15    0.0       0.0    0.0
# 3          17    0.0       0.0    0.0
# 4          18    0.0       0.0    0.0
# 5          19    0.0       0.0    0.0
# 6          20    0.0       0.0    0.0
# 7          21    0.0       0.0    0.0
# 8          22    0.0       0.0    0.0
# 10         24    0.0       0.0    0.0
# 11         25    0.0       0.0    0.0

# %%
df.describe()
# Out:
#          timestamp        steer     throttle        break
# count  1755.000000  1755.000000  1755.000000  1755.000000
# mean   2472.121937     0.000649     0.387471     0.096299
# std    1410.469514     0.084430     0.173614     0.294381
# min      14.000000    -0.336534     0.000000     0.000000
# 25%    1298.500000    -0.001641     0.379370     0.000000
# 50%    2567.000000     0.000000     0.379372     0.000000
# 75%    3712.500000     0.001921     0.383999     0.000000
# max    4916.000000     0.511645     0.700000     1.000000

# %%
plt.plot(df['steer'])

# %%
plt.plot(df['throttle'])

# %%
df = df.round(4)

# %%
df.describe()
# Out:
#          timestamp        steer     throttle        break
# count  1755.000000  1755.000000  1755.000000  1755.000000
# mean   2472.121937     0.000647     0.387483     0.096299
# std    1410.469514     0.084431     0.173613     0.294381
# min      14.000000    -0.336500     0.000000     0.000000
# 25%    1298.500000    -0.001600     0.379400     0.000000
# 50%    2567.000000     0.000000     0.379400     0.000000
# 75%    3712.500000     0.001900     0.384000     0.000000
# max    4916.000000     0.511600     0.700000     1.000000

# %%
df.to_csv("clean_data.csv", index=False)
